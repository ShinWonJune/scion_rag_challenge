# %%
# config_path="../configs/query_encoder/config_PwC-Embedding_expr.json"
# data_schema="/workspace/configs/csv_schema/test_2.json"
# docs_jsonl_path="/workspace/results/searched_docs_db/search_documents_test.jsonl"
# auto_data_load=True

# %%
CONFIG_FILE = "../configs/query_encoder/config_gte-multilingual-base.json"

# %%
from build_vectordb_search import build_vectordb_search

build_vectordb_search(
    config_path=CONFIG_FILE,
    data_schema="/workspace/configs/csv_schema/test_2.json",
    docs_jsonl_path="/workspace/data/expr/search_documents_20250912_013206.jsonl",
    auto_data_load=False,
)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/transformers/utils/hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Loading documents from /workspace/data/expr/search_documents_20250912_013206.jsonl: Auto Loading Data False
# Loaded 2250 documents
# 모델 로딩: Alibaba-NLP/gte-multilingual-base (임베딩 차원을 1024으로 조절합니다)
# A new version of the following files was downloaded from https://huggingface.co/Alibaba-NLP/new-impl:
# - configuration.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/Alibaba-NLP/new-impl:
# - modeling.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 문서 인코딩 중...
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]

# %%
import subprocess
import shlex

def run_command():
    """
    Constructs and executes the specified command using subprocess.
    """
    # --- Parameters ---
    script_name = "multi_hop_to_single_hop.py"
    input_file = "../data/rag_test_data/questions.jsonl"
    output_file = "../data/expr/singlehop_decompose.jsonl"
    question_field = "question"
    context_field = "context"
    mode = "decompose"
    model = "gemini-2.5-flash"

    # --- Command Construction ---
    # Using f-string to build the command string
    command_str = (
        f"python {script_name} "
        f"--input {shlex.quote(input_file)} "
        f"--output {shlex.quote(output_file)} "
        f"--question_field {shlex.quote(question_field)} "
        f"--context_field {shlex.quote(context_field)} "
        f"--mode {shlex.quote(mode)} "
        f"--model {shlex.quote(model)}"
    )

    print(f"🚀 Executing Command:\n{command_str}\n" + "-"*50)

    # --- Command Execution ---
    try:
        # Using shlex.split to handle arguments properly
        args = shlex.split(command_str)
        
        # Execute the command
        result = subprocess.run(
            args,
            check=True,        # Raise an exception if the command fails
            text=True,         # Capture stdout/stderr as text
            capture_output=True # Capture stdout and stderr
        )
        
        print("✅ Command Executed Successfully!")
        print("--- Standard Output (stdout) ---")
        print(result.stdout)
        if result.stderr:
            print("--- Standard Error (stderr) ---")
            print(result.stderr)

    except FileNotFoundError:
        print(f"❌ Error: The script '{script_name}' was not found.")
    except subprocess.CalledProcessError as e:
        print(f"❌ Command Failed with exit code {e.returncode}")
        print("--- Standard Output (stdout) ---")
        print(e.stdout)
        print("--- Standard Error (stderr) ---")
        print(e.stderr)
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    run_command()

# %%
from retrieval_system.main import main

# %%
import subprocess
import shlex

def run_bash_command():
    """
    주어진 Bash 명령어를 Python에서 실행하고 결과를 출력합니다.
    """
    # 실행할 Bash 명령어
    questions_path = "/app/data/rag_test_data/questions.jsonl"
    data_range = "1-50"
    top_k = 50
    device = "auto"
    schema_path = "/workspace/configs/csv_schema/test_3.json"

    # f-string을 사용하여 변수를 조합한 명령어 문자열 생성
    command_str = (
        f"python -m retrieval_system.main "
        f"--config_json {CONFIG_FILE} "
        f"--questions_jsonl {questions_path} "
        f"--range {data_range} "
        f"--top_k {top_k} "
        f"--device {device} "
        f"--schema_json {schema_path}"
    )

    # 명령어를 안전하게 리스트 형태로 분리 (shlex.split 사용 권장)
    command_list = shlex.split(command_str)
    
    print("🚀 실행할 명령어:")
    # 보기 좋게 출력하기 위해 각 인자를 줄바꿈하여 표시
    print(" \\\n    ".join(command_list))
    print("-" * 50)

    try:
        # subprocess.run을 사용하여 명령어 실행
        # check=True: 명령이 실패하면 CalledProcessError를 발생시킴
        # capture_output=True: stdout과 stderr를 캡처함
        # text=True: stdout과 stderr를 문자열로 디코딩함
        result = subprocess.run(
            command_list, 
            check=True, 
            capture_output=True, 
            text=True, 
            encoding='utf-8'
        )

        print("✅ 명령 실행 성공!")
        print("\n--- 표준 출력 (stdout) ---")
        print(result.stdout)
        
        # 표준 오류가 있다면 출력
        if result.stderr:
            print("\n--- 표준 오류 (stderr) ---")
            print(result.stderr)

    except FileNotFoundError:
        print(f"❌ 오류: '{command_list[0]}' 명령을 찾을 수 없습니다. 경로를 확인해주세요.")
        
    except subprocess.CalledProcessError as e:
        # 명령 실행 중 오류가 발생한 경우
        print(f"❌ 명령 실행 실패! (Return Code: {e.returncode})")
        print("\n--- 표준 출력 (stdout) ---")
        print(e.stdout)
        print("\n--- 표준 오류 (stderr) ---")
        print(e.stderr)

# 함수 실행
if __name__ == "__main__":
    run_bash_command()
# Out:
# 🚀 실행할 명령어:
# python \
#     -m \
#     retrieval_system.main \
#     --config_json \
#     ../configs/query_encoder/config_gte-multilingual-base.json \
#     --questions_jsonl \
#     /workspace/data/expr/singlehop_decompose.jsonl \
#     --range \
#     1-50 \
#     --top_k \
#     50 \
#     --device \
#     auto \
#     --schema_json \
#     /workspace/configs/csv_schema/test_3.json
# --------------------------------------------------
# ✅ 명령 실행 성공!
#
# --- 표준 출력 (stdout) ---
# ../results/vectordb/250912_062141/vector_db_gte_test_Alibaba-NLP_gte-multilingual-base.csv
#
# --- Retrieval Complete ---
# Output folder: ../results/retrieval_docs/250912_182734
# Saved files:
# - ../results/retrieval_docs/250912_182734/row_000001_Alibaba-NLP-gte-multilingual-base_345b050d.json
# - ../results/retrieval_docs/250912_182734/row_000002_Alibaba-NLP-gte-multilingual-base_39e07752.json
# - ../results/retrieval_docs/250912_182734/row_000003_Alibaba-NLP-gte-multilingual-base_39cf3a9e.json
# - ../results/retrieval_docs/250912_182734/row_000004_Alibaba-NLP-gte-multilingual-base_df6cefcc.json
# - ../results/retrieval_docs/250912_182734/row_000005_Alibaba-NLP-gte-multilingual-base_70a2b9a2.json
# - ../results/retrieval_docs/250912_182734/row_000006_Alibaba-NLP-gte-multilingual-base_ef1673b5.json
# - ../results/retrieval_docs/250912_182734/row_000007_Alibaba-NLP-gte-multilingual-base_70411d8b.json
# - ../results/retrieval_docs/250912_182734/row_000008_Alibaba-NLP-gte-multilingual-base_33bef81a.json
# - ../results/retrieval_docs/250912_182734/row_000009_Alibaba-NLP-gte-multilingual-base_497f7f2a.json
# - ../results/retrieval_docs/250912_182734/row_000010_Alibaba-NLP-gte-multilingual-base_4cad44fb.json
# - ../results/retrieval_docs/250912_182734/row_000011_Alibaba-NLP-gte-multilingual-base_0cf06061.json
# - ../results/retrieval_docs/250912_182734/row_000012_Alibaba-NLP-gte-multilingual-base_5d02b263.json
# - ../results/retrieval_docs/250912_182734/row_000013_Alibaba-NLP-gte-multilingual-base_b9b500bb.json
# - ../results/retrieval_docs/250912_182734/row_000014_Alibaba-NLP-gte-multilingual-base_aadee767.json
# - ../results/retrieval_docs/250912_182734/row_000015_Alibaba-NLP-gte-multilingual-base_56ca4719.json
# - ../results/retrieval_docs/250912_182734/row_000016_Alibaba-NLP-gte-multilingual-base_00f6d4a2.json
# - ../results/retrieval_docs/250912_182734/row_000017_Alibaba-NLP-gte-multilingual-base_1510d32d.json
# - ../results/retrieval_docs/250912_182734/row_000018_Alibaba-NLP-gte-multilingual-base_2b03b0c2.json
# - ../results/retrieval_docs/250912_182734/row_000019_Alibaba-NLP-gte-multilingual-base_9a815a68.json
# - ../results/retrieval_docs/250912_182734/row_000020_Alibaba-NLP-gte-multilingual-base_e00352f3.json
# - ../results/retrieval_docs/250912_182734/row_000021_Alibaba-NLP-gte-multilingual-base_8588f043.json
# - ../results/retrieval_docs/250912_182734/row_000022_Alibaba-NLP-gte-multilingual-base_dfcba2d2.json
# - ../results/retrieval_docs/250912_182734/row_000023_Alibaba-NLP-gte-multilingual-base_8b30d2d8.json
# - ../results/retrieval_docs/250912_182734/row_000024_Alibaba-NLP-gte-multilingual-base_382ab648.json
# - ../results/retrieval_docs/250912_182734/row_000025_Alibaba-NLP-gte-multilingual-base_73190846.json
# - ../results/retrieval_docs/250912_182734/row_000026_Alibaba-NLP-gte-multilingual-base_3bc47eb9.json
# - ../results/retrieval_docs/250912_182734/row_000027_Alibaba-NLP-gte-multilingual-base_2876cd56.json
# - ../results/retrieval_docs/250912_182734/row_000028_Alibaba-NLP-gte-multilingual-base_d9521c53.json
# - ../results/retrieval_docs/250912_182734/row_000029_Alibaba-NLP-gte-multilingual-base_7d5acbd8.json
# - ../results/retrieval_docs/250912_182734/row_000030_Alibaba-NLP-gte-multilingual-base_dfdfb181.json
# - ../results/retrieval_docs/250912_182734/row_000031_Alibaba-NLP-gte-multilingual-base_9c35c0ae.json
# - ../results/retrieval_docs/250912_182734/row_000032_Alibaba-NLP-gte-multilingual-base_8c15543b.json
# - ../results/retrieval_docs/250912_182734/row_000033_Alibaba-NLP-gte-multilingual-base_820896ec.json
# - ../results/retrieval_docs/250912_182734/row_000034_Alibaba-NLP-gte-multilingual-base_28da16c7.json
# - ../results/retrieval_docs/250912_182734/row_000035_Alibaba-NLP-gte-multilingual-base_c8957abf.json
# - ../results/retrieval_docs/250912_182734/row_000036_Alibaba-NLP-gte-multilingual-base_ea0b7c1c.json
# - ../results/retrieval_docs/250912_182734/row_000037_Alibaba-NLP-gte-multilingual-base_9fda1080.json
# - ../results/retrieval_docs/250912_182734/row_000038_Alibaba-NLP-gte-multilingual-base_8048cd9b.json
# - ../results/retrieval_docs/250912_182734/row_000039_Alibaba-NLP-gte-multilingual-base_a698801e.json
# - ../results/retrieval_docs/250912_182734/row_000040_Alibaba-NLP-gte-multilingual-base_5dd0e73e.json
# - ../results/retrieval_docs/250912_182734/row_000041_Alibaba-NLP-gte-multilingual-base_5caebc06.json
# - ../results/retrieval_docs/250912_182734/row_000042_Alibaba-NLP-gte-multilingual-base_b41d6112.json
# - ../results/retrieval_docs/250912_182734/row_000043_Alibaba-NLP-gte-multilingual-base_f3211c21.json
# - ../results/retrieval_docs/250912_182734/row_000044_Alibaba-NLP-gte-multilingual-base_ba1c6c79.json
# - ../results/retrieval_docs/250912_182734/row_000045_Alibaba-NLP-gte-multilingual-base_0ddc7949.json
# - ../results/retrieval_docs/250912_182734/row_000046_Alibaba-NLP-gte-multilingual-base_b8fa9d72.json
# - ../results/retrieval_docs/250912_182734/row_000047_Alibaba-NLP-gte-multilingual-base_e1abfbb2.json
# - ../results/retrieval_docs/250912_182734/row_000048_Alibaba-NLP-gte-multilingual-base_a19a8940.json
# - ../results/retrieval_docs/250912_182734/row_000049_Alibaba-NLP-gte-multilingual-base_01006360.json
# - ../results/retrieval_docs/250912_182734/row_000050_Alibaba-NLP-gte-multilingual-base_a465a2b6.json
#
#
# --- 표준 오류 (stderr) ---
# [INFO] Loading resources...
# /home/vscode/.local/lib/python3.11/site-packages/transformers/utils/hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# A new version of the following files was downloaded from https://huggingface.co/Alibaba-NLP/new-impl:
# - configuration.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/Alibaba-NLP/new-impl:
# - modeling.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [INFO] FAISS not found or disabled. Using NumPy for retrieval (slower).
# [INFO] Resources loaded successfully.
# [INFO] Selected 50 question(s) to process.
# [OK] Saved result for QID row_000001 to ../results/retrieval_docs/250912_182734/row_000001_Alibaba-NLP-gte-multilingual-base_345b050d.json
# [OK] Saved result for QID row_000002 to ../results/retrieval_docs/250912_182734/row_000002_Alibaba-NLP-gte-multilingual-base_39e07752.json
# [OK] Saved result for QID row_000003 to ../results/retrieval_docs/250912_182734/row_000003_Alibaba-NLP-gte-multilingual-base_39cf3a9e.json
# [OK] Saved result for QID row_000004 to ../results/retrieval_docs/250912_182734/row_000004_Alibaba-NLP-gte-multilingual-base_df6cefcc.json
# [OK] Saved result for QID row_000005 to ../results/retrieval_docs/250912_182734/row_000005_Alibaba-NLP-gte-multilingual-base_70a2b9a2.json
# [OK] Saved result for QID row_000006 to ../results/retrieval_docs/250912_182734/row_000006_Alibaba-NLP-gte-multilingual-base_ef1673b5.json
# [OK] Saved result for QID row_000007 to ../results/retrieval_docs/250912_182734/row_000007_Alibaba-NLP-gte-multilingual-base_70411d8b.json
# [OK] Saved result for QID row_000008 to ../results/retrieval_docs/250912_182734/row_000008_Alibaba-NLP-gte-multilingual-base_33bef81a.json
# [OK] Saved result for QID row_000009 to ../results/retrieval_docs/250912_182734/row_000009_Alibaba-NLP-gte-multilingual-base_497f7f2a.json
# [OK] Saved result for QID row_000010 to ../results/retrieval_docs/250912_182734/row_000010_Alibaba-NLP-gte-multilingual-base_4cad44fb.json
# [OK] Saved result for QID row_000011 to ../results/retrieval_docs/250912_182734/row_000011_Alibaba-NLP-gte-multilingual-base_0cf06061.json
# [OK] Saved result for QID row_000012 to ../results/retrieval_docs/250912_182734/row_000012_Alibaba-NLP-gte-multilingual-base_5d02b263.json
# [OK] Saved result for QID row_000013 to ../results/retrieval_docs/250912_182734/row_000013_Alibaba-NLP-gte-multilingual-base_b9b500bb.json
# [OK] Saved result for QID row_000014 to ../results/retrieval_docs/250912_182734/row_000014_Alibaba-NLP-gte-multilingual-base_aadee767.json
# [OK] Saved result for QID row_000015 to ../results/retrieval_docs/250912_182734/row_000015_Alibaba-NLP-gte-multilingual-base_56ca4719.json
# [OK] Saved result for QID row_000016 to ../results/retrieval_docs/250912_182734/row_000016_Alibaba-NLP-gte-multilingual-base_00f6d4a2.json
# [OK] Saved result for QID row_000017 to ../results/retrieval_docs/250912_182734/row_000017_Alibaba-NLP-gte-multilingual-base_1510d32d.json
# [OK] Saved result for QID row_000018 to ../results/retrieval_docs/250912_182734/row_000018_Alibaba-NLP-gte-multilingual-base_2b03b0c2.json
# [OK] Saved result for QID row_000019 to ../results/retrieval_docs/250912_182734/row_000019_Alibaba-NLP-gte-multilingual-base_9a815a68.json
# [OK] Saved result for QID row_000020 to ../results/retrieval_docs/250912_182734/row_000020_Alibaba-NLP-gte-multilingual-base_e00352f3.json
# [OK] Saved result for QID row_000021 to ../results/retrieval_docs/250912_182734/row_000021_Alibaba-NLP-gte-multilingual-base_8588f043.json
# [OK] Saved result for QID row_000022 to ../results/retrieval_docs/250912_182734/row_000022_Alibaba-NLP-gte-multilingual-base_dfcba2d2.json
# [OK] Saved result for QID row_000023 to ../results/retrieval_docs/250912_182734/row_000023_Alibaba-NLP-gte-multilingual-base_8b30d2d8.json
# [OK] Saved result for QID row_000024 to ../results/retrieval_docs/250912_182734/row_000024_Alibaba-NLP-gte-multilingual-base_382ab648.json
# [OK] Saved result for QID row_000025 to ../results/retrieval_docs/250912_182734/row_000025_Alibaba-NLP-gte-multilingual-base_73190846.json
# [OK] Saved result for QID row_000026 to ../results/retrieval_docs/250912_182734/row_000026_Alibaba-NLP-gte-multilingual-base_3bc47eb9.json
# [OK] Saved result for QID row_000027 to ../results/retrieval_docs/250912_182734/row_000027_Alibaba-NLP-gte-multilingual-base_2876cd56.json
# [OK] Saved result for QID row_000028 to ../results/retrieval_docs/250912_182734/row_000028_Alibaba-NLP-gte-multilingual-base_d9521c53.json
# [OK] Saved result for QID row_000029 to ../results/retrieval_docs/250912_182734/row_000029_Alibaba-NLP-gte-multilingual-base_7d5acbd8.json
# [OK] Saved result for QID row_000030 to ../results/retrieval_docs/250912_182734/row_000030_Alibaba-NLP-gte-multilingual-base_dfdfb181.json
# [OK] Saved result for QID row_000031 to ../results/retrieval_docs/250912_182734/row_000031_Alibaba-NLP-gte-multilingual-base_9c35c0ae.json
# [OK] Saved result for QID row_000032 to ../results/retrieval_docs/250912_182734/row_000032_Alibaba-NLP-gte-multilingual-base_8c15543b.json
# [OK] Saved result for QID row_000033 to ../results/retrieval_docs/250912_182734/row_000033_Alibaba-NLP-gte-multilingual-base_820896ec.json
# [OK] Saved result for QID row_000034 to ../results/retrieval_docs/250912_182734/row_000034_Alibaba-NLP-gte-multilingual-base_28da16c7.json
# [OK] Saved result for QID row_000035 to ../results/retrieval_docs/250912_182734/row_000035_Alibaba-NLP-gte-multilingual-base_c8957abf.json
# [OK] Saved result for QID row_000036 to ../results/retrieval_docs/250912_182734/row_000036_Alibaba-NLP-gte-multilingual-base_ea0b7c1c.json
# [OK] Saved result for QID row_000037 to ../results/retrieval_docs/250912_182734/row_000037_Alibaba-NLP-gte-multilingual-base_9fda1080.json
# [OK] Saved result for QID row_000038 to ../results/retrieval_docs/250912_182734/row_000038_Alibaba-NLP-gte-multilingual-base_8048cd9b.json
# [OK] Saved result for QID row_000039 to ../results/retrieval_docs/250912_182734/row_000039_Alibaba-NLP-gte-multilingual-base_a698801e.json
# [OK] Saved result for QID row_000040 to ../results/retrieval_docs/250912_182734/row_000040_Alibaba-NLP-gte-multilingual-base_5dd0e73e.json
# [OK] Saved result for QID row_000041 to ../results/retrieval_docs/250912_182734/row_000041_Alibaba-NLP-gte-multilingual-base_5caebc06.json
# [OK] Saved result for QID row_000042 to ../results/retrieval_docs/250912_182734/row_000042_Alibaba-NLP-gte-multilingual-base_b41d6112.json
# [OK] Saved result for QID row_000043 to ../results/retrieval_docs/250912_182734/row_000043_Alibaba-NLP-gte-multilingual-base_f3211c21.json
# [OK] Saved result for QID row_000044 to ../results/retrieval_docs/250912_182734/row_000044_Alibaba-NLP-gte-multilingual-base_ba1c6c79.json
# [OK] Saved result for QID row_000045 to ../results/retrieval_docs/250912_182734/row_000045_Alibaba-NLP-gte-multilingual-base_0ddc7949.json
# [OK] Saved result for QID row_000046 to ../results/retrieval_docs/250912_182734/row_000046_Alibaba-NLP-gte-multilingual-base_b8fa9d72.json
# [OK] Saved result for QID row_000047 to ../results/retrieval_docs/250912_182734/row_000047_Alibaba-NLP-gte-multilingual-base_e1abfbb2.json
# [OK] Saved result for QID row_000048 to ../results/retrieval_docs/250912_182734/row_000048_Alibaba-NLP-gte-multilingual-base_a19a8940.json
# [OK] Saved result for QID row_000049 to ../results/retrieval_docs/250912_182734/row_000049_Alibaba-NLP-gte-multilingual-base_01006360.json
# [OK] Saved result for QID row_000050 to ../results/retrieval_docs/250912_182734/row_000050_Alibaba-NLP-gte-multilingual-base_a465a2b6.json

# %%
import subprocess

def run_preprocessing():
    """
    전처리 및 답변 생성 스크립트를 변수를 사용하여 실행합니다.
    """
    # ----------------------------------------------------
    # ✅ 각 인자를 변수로 분리하여 관리
    # ----------------------------------------------------
    input_dir = "/workspace/results/retrieval_docs/250912_182734/"
    max_rank = 5
    is_parallel = False  # 불리언(Boolean) 값으로 관리

    # ----------------------------------------------------
    # ✅ 리스트 형태로 명령어를 구성
    # ----------------------------------------------------
    command_list = [
        "python",
        "preprocess_and_generate_answer.py",
        "--input_dir", input_dir,
        "--max_rank", str(max_rank),        # 💡 숫자는 str()로 감싸 문자열로 변환합니다.
        # "--parallel", str(is_parallel),    # 💡 불리언도 str()로 감싸 'True'/'False' 문자열로 변환합니다. this makes result in correct
    ]

    print("🚀 실행할 명령어:")
    # 보기 좋게 한 줄씩 출력
    print(" \\\n    ".join(command_list))
    print("-" * 50)

    try:
        # command_list를 subprocess.run에 바로 전달
        result = subprocess.run(
            command_list, 
            check=True, 
            capture_output=True, 
            text=True,
            encoding='utf-8'
        )

        print("✅ 명령 실행 성공!")
        print("\n--- 표준 출력 (stdout) ---")
        print(result.stdout)
        
        if result.stderr:
            print("\n--- 표준 오류 (stderr) ---")
            print(result.stderr)

    except FileNotFoundError:
        print(f"❌ 오류: 'python' 또는 스크립트 파일을 찾을 수 없습니다. 경로를 확인해주세요.")

    except subprocess.CalledProcessError as e:
        print(f"❌ 명령 실행 실패! (Return Code: {e.returncode})")
        print("\n--- 표준 출력 (stdout) ---")
        print(e.stdout)
        print("\n--- 표준 오류 (stderr) ---")
        print(e.stderr)

# 함수 실행
if __name__ == "__main__":
    run_preprocessing()
# Out:
# 🚀 실행할 명령어:
# python \
#     preprocess_and_generate_answer.py \
#     --input_dir \
#     /workspace/results/retrieval_docs/250912_182734/ \
#     --max_rank \
#     5 \
#     --parallel \
#     True
# --------------------------------------------------
# ✅ 명령 실행 성공!
#
# --- 표준 출력 (stdout) ---
# Starting parallel processing for 50 files with max 10 workers...
# --- Processing file: row_000024_Alibaba-NLP-gte-multilingual-base_382ab648.json ---
# --- Processing file: row_000021_Alibaba-NLP-gte-multilingual-base_8588f043.json ---
# --- Processing file: row_000011_Alibaba-NLP-gte-multilingual-base_0cf06061.json ---
# --- Processing file: row_000039_Alibaba-NLP-gte-multilingual-base_a698801e.json ---
# --- Processing file: row_000033_Alibaba-NLP-gte-multilingual-base_820896ec.json ---
# --- Processing file: row_000023_Alibaba-NLP-gte-multilingual-base_8b30d2d8.json ---
# --- Processing file: row_000040_Alibaba-NLP-gte-multilingual-base_5dd0e73e.json ---
# --- Processing file: row_000031_Alibaba-NLP-gte-multilingual-base_9c35c0ae.json ---
# --- Processing file: row_000010_Alibaba-NLP-gte-multilingual-base_4cad44fb.json ---
# --- Processing file: row_000030_Alibaba-NLP-gte-multilingual-base_dfdfb181.json ---
# Successfully processed file row_000011_Alibaba-NLP-gte-multilingual-base_0cf06061.json.
# --- Processing file: row_000036_Alibaba-NLP-gte-multilingual-base_ea0b7c1c.json ---
# Successfully processed file row_000031_Alibaba-NLP-gte-multilingual-base_9c35c0ae.json.
# --- Processing file: row_000013_Alibaba-NLP-gte-multilingual-base_b9b500bb.json ---
# Successfully processed file row_000040_Alibaba-NLP-gte-multilingual-base_5dd0e73e.json.
# --- Processing file: row_000035_Alibaba-NLP-gte-multilingual-base_c8957abf.json ---
# Successfully processed file row_000030_Alibaba-NLP-gte-multilingual-base_dfdfb181.json.
# --- Processing file: row_000004_Alibaba-NLP-gte-multilingual-base_df6cefcc.json ---
# Successfully processed file row_000021_Alibaba-NLP-gte-multilingual-base_8588f043.json.
# --- Processing file: row_000047_Alibaba-NLP-gte-multilingual-base_e1abfbb2.json ---
# Successfully processed file row_000023_Alibaba-NLP-gte-multilingual-base_8b30d2d8.json.
# --- Processing file: row_000041_Alibaba-NLP-gte-multilingual-base_5caebc06.json ---
# Successfully processed file row_000033_Alibaba-NLP-gte-multilingual-base_820896ec.json.
# --- Processing file: row_000050_Alibaba-NLP-gte-multilingual-base_a465a2b6.json ---
# Successfully processed file row_000013_Alibaba-NLP-gte-multilingual-base_b9b500bb.json.
# --- Processing file: row_000017_Alibaba-NLP-gte-multilingual-base_1510d32d.json ---
# Attempt 1 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 1 failed for a request: Expecting value: line 1 column 1 (char 0)
# Attempt 1 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Successfully processed file row_000035_Alibaba-NLP-gte-multilingual-base_c8957abf.json.
# --- Processing file: row_000003_Alibaba-NLP-gte-multilingual-base_39cf3a9e.json ---
# Successfully processed file row_000041_Alibaba-NLP-gte-multilingual-base_5caebc06.json.
# --- Processing file: row_000048_Alibaba-NLP-gte-multilingual-base_a19a8940.json ---
# Successfully processed file row_000036_Alibaba-NLP-gte-multilingual-base_ea0b7c1c.json.
# --- Processing file: row_000042_Alibaba-NLP-gte-multilingual-base_b41d6112.json ---
# Successfully processed file row_000047_Alibaba-NLP-gte-multilingual-base_e1abfbb2.json.
# --- Processing file: row_000032_Alibaba-NLP-gte-multilingual-base_8c15543b.json ---
# Successfully processed file row_000050_Alibaba-NLP-gte-multilingual-base_a465a2b6.json.
# --- Processing file: row_000005_Alibaba-NLP-gte-multilingual-base_70a2b9a2.json ---
# Successfully processed file row_000003_Alibaba-NLP-gte-multilingual-base_39cf3a9e.json.
# --- Processing file: row_000006_Alibaba-NLP-gte-multilingual-base_ef1673b5.json ---
# Successfully processed file row_000017_Alibaba-NLP-gte-multilingual-base_1510d32d.json.
# --- Processing file: row_000026_Alibaba-NLP-gte-multilingual-base_3bc47eb9.json ---
# Attempt 1 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Successfully processed file row_000032_Alibaba-NLP-gte-multilingual-base_8c15543b.json.
# --- Processing file: row_000028_Alibaba-NLP-gte-multilingual-base_d9521c53.json ---
# Successfully processed file row_000039_Alibaba-NLP-gte-multilingual-base_a698801e.json.
# --- Processing file: row_000029_Alibaba-NLP-gte-multilingual-base_7d5acbd8.json ---
# Attempt 2 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Successfully processed file row_000005_Alibaba-NLP-gte-multilingual-base_70a2b9a2.json.
# --- Processing file: row_000025_Alibaba-NLP-gte-multilingual-base_73190846.json ---
# Attempt 2 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Successfully processed file row_000048_Alibaba-NLP-gte-multilingual-base_a19a8940.json.
# --- Processing file: row_000043_Alibaba-NLP-gte-multilingual-base_f3211c21.json ---
# Successfully processed file row_000028_Alibaba-NLP-gte-multilingual-base_d9521c53.json.
# --- Processing file: row_000037_Alibaba-NLP-gte-multilingual-base_9fda1080.json ---
# Attempt 1 failed for a request: Expecting value: line 1 column 1 (char 0)
# Successfully processed file row_000029_Alibaba-NLP-gte-multilingual-base_7d5acbd8.json.
# --- Processing file: row_000045_Alibaba-NLP-gte-multilingual-base_0ddc7949.json ---
# Attempt 1 failed for a request: Expecting value: line 1 column 1 (char 0)
# Attempt 1 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 2 failed for a request: Expecting value: line 1 column 1 (char 0)
# Successfully processed file row_000043_Alibaba-NLP-gte-multilingual-base_f3211c21.json.
# --- Processing file: row_000009_Alibaba-NLP-gte-multilingual-base_497f7f2a.json ---
# Successfully processed file row_000045_Alibaba-NLP-gte-multilingual-base_0ddc7949.json.
# --- Processing file: row_000020_Alibaba-NLP-gte-multilingual-base_e00352f3.json ---
# Attempt 2 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 3 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# --- Processing file: row_000001_Alibaba-NLP-gte-multilingual-base_345b050d.json ---
# File 'row_000024_Alibaba-NLP-gte-multilingual-base_382ab648.json' generated an exception: Gemini call failed after 3 attempts: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 1 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 1 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 3 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# --- Processing file: row_000034_Alibaba-NLP-gte-multilingual-base_28da16c7.json ---
# File 'row_000010_Alibaba-NLP-gte-multilingual-base_4cad44fb.json' generated an exception: Gemini call failed after 3 attempts: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 2 failed for a request: Expecting value: line 1 column 1 (char 0)
# Attempt 2 failed for a request: Expecting value: line 1 column 1 (char 0)
# Attempt 3 failed for a request: Expecting value: line 1 column 1 (char 0)
# --- Processing file: row_000027_Alibaba-NLP-gte-multilingual-base_2876cd56.json ---
# File 'row_000004_Alibaba-NLP-gte-multilingual-base_df6cefcc.json' generated an exception: Gemini call failed after 3 attempts: Expecting value: line 1 column 1 (char 0)
# Successfully processed file row_000001_Alibaba-NLP-gte-multilingual-base_345b050d.json.
# --- Processing file: row_000019_Alibaba-NLP-gte-multilingual-base_9a815a68.json ---
# Successfully processed file row_000020_Alibaba-NLP-gte-multilingual-base_e00352f3.json.
# --- Processing file: row_000022_Alibaba-NLP-gte-multilingual-base_dfcba2d2.json ---
# Attempt 1 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Successfully processed file row_000042_Alibaba-NLP-gte-multilingual-base_b41d6112.json.
# --- Processing file: row_000016_Alibaba-NLP-gte-multilingual-base_00f6d4a2.json ---
# Successfully processed file row_000034_Alibaba-NLP-gte-multilingual-base_28da16c7.json.
# --- Processing file: row_000014_Alibaba-NLP-gte-multilingual-base_aadee767.json ---
# Attempt 2 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 2 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Successfully processed file row_000016_Alibaba-NLP-gte-multilingual-base_00f6d4a2.json.
# --- Processing file: row_000015_Alibaba-NLP-gte-multilingual-base_56ca4719.json ---
# Attempt 3 failed for a request: Expecting value: line 1 column 1 (char 0)
# --- Processing file: row_000018_Alibaba-NLP-gte-multilingual-base_2b03b0c2.json ---
# File 'row_000006_Alibaba-NLP-gte-multilingual-base_ef1673b5.json' generated an exception: Gemini call failed after 3 attempts: Expecting value: line 1 column 1 (char 0)
# Attempt 3 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# --- Processing file: row_000049_Alibaba-NLP-gte-multilingual-base_01006360.json ---
# File 'row_000026_Alibaba-NLP-gte-multilingual-base_3bc47eb9.json' generated an exception: Gemini call failed after 3 attempts: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 1 failed for a request: Expecting value: line 1 column 1 (char 0)
# Successfully processed file row_000022_Alibaba-NLP-gte-multilingual-base_dfcba2d2.json.
# --- Processing file: row_000038_Alibaba-NLP-gte-multilingual-base_8048cd9b.json ---
# Attempt 1 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 1 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Attempt 2 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Attempt 2 failed for a request: Expecting value: line 1 column 1 (char 0)
# Attempt 2 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Attempt 1 failed for a request: Expecting value: line 1 column 1 (char 0)
# Attempt 3 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# --- Processing file: row_000044_Alibaba-NLP-gte-multilingual-base_ba1c6c79.json ---
# File 'row_000019_Alibaba-NLP-gte-multilingual-base_9a815a68.json' generated an exception: Gemini call failed after 3 attempts: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# Successfully processed file row_000049_Alibaba-NLP-gte-multilingual-base_01006360.json.
# --- Processing file: row_000007_Alibaba-NLP-gte-multilingual-base_70411d8b.json ---
# Attempt 3 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# --- Processing file: row_000012_Alibaba-NLP-gte-multilingual-base_5d02b263.json ---
# File 'row_000038_Alibaba-NLP-gte-multilingual-base_8048cd9b.json' generated an exception: Gemini call failed after 3 attempts: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# Attempt 3 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# --- Processing file: row_000002_Alibaba-NLP-gte-multilingual-base_39e07752.json ---
# File 'row_000009_Alibaba-NLP-gte-multilingual-base_497f7f2a.json' generated an exception: Gemini call failed after 3 attempts: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# Attempt 2 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Successfully processed file row_000018_Alibaba-NLP-gte-multilingual-base_2b03b0c2.json.
# --- Processing file: row_000046_Alibaba-NLP-gte-multilingual-base_b8fa9d72.json ---
# Attempt 1 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Attempt 1 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Attempt 1 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Attempt 1 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Attempt 1 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Attempt 3 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# --- Processing file: row_000008_Alibaba-NLP-gte-multilingual-base_33bef81a.json ---
# File 'row_000025_Alibaba-NLP-gte-multilingual-base_73190846.json' generated an exception: Gemini call failed after 3 attempts: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 2 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Attempt 2 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Attempt 2 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Attempt 1 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Attempt 1 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 2 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Attempt 3 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# File 'row_000037_Alibaba-NLP-gte-multilingual-base_9fda1080.json' generated an exception: Gemini call failed after 3 attempts: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 2 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Attempt 3 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# File 'row_000014_Alibaba-NLP-gte-multilingual-base_aadee767.json' generated an exception: Gemini call failed after 3 attempts: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# Attempt 2 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# Attempt 3 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# File 'row_000007_Alibaba-NLP-gte-multilingual-base_70411d8b.json' generated an exception: Gemini call failed after 3 attempts: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# Attempt 3 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# File 'row_000046_Alibaba-NLP-gte-multilingual-base_b8fa9d72.json' generated an exception: Gemini call failed after 3 attempts: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# Attempt 3 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# File 'row_000012_Alibaba-NLP-gte-multilingual-base_5d02b263.json' generated an exception: Gemini call failed after 3 attempts: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# Attempt 3 failed for a request: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# File 'row_000008_Alibaba-NLP-gte-multilingual-base_33bef81a.json' generated an exception: Gemini call failed after 3 attempts: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_paid_tier_input_token_count"
#   quota_id: "GenerateContentPaidTierInputTokensPerModelPerMinute"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Successfully processed file row_000027_Alibaba-NLP-gte-multilingual-base_2876cd56.json.
# Attempt 3 failed for a request: Expecting value: line 1 column 1 (char 0)
# File 'row_000044_Alibaba-NLP-gte-multilingual-base_ba1c6c79.json' generated an exception: Gemini call failed after 3 attempts: Expecting value: line 1 column 1 (char 0)
# Attempt 3 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# File 'row_000002_Alibaba-NLP-gte-multilingual-base_39e07752.json' generated an exception: Gemini call failed after 3 attempts: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 2 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# Attempt 3 failed for a request: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
# File 'row_000015_Alibaba-NLP-gte-multilingual-base_56ca4719.json' generated an exception: Gemini call failed after 3 attempts: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 2.
#
# ==================================================
#            PARALLEL PROCESSING COMPLETE
# ==================================================
#
#
# ✅ Successfully processed 32 out of 50 files.
# Total execution time: 85.33 seconds.

# %%
import os 
import datetime
from final_result import process_json_files, append_new_data_frame_to_base_csv
# Define the path to your JSON files.
# IMPORTANT: Replace this with the actual path to your files.
# For example: '/workspace/results/final_result/'
# 현재 날짜와 시간을 가져옵니다.
now = datetime.datetime.now()

# 원하는 형식(yymmdd_hhmmss)으로 문자열을 만듭니다.
timestamp_str = now.strftime("%y%m%d_%H%M%S")
retrival_docs_folder = "/workspace/data/expr/final_result"
output_directory = (
    "/workspace/data/expr/competition_submission/" + timestamp_str + "/"
)  # Assuming the files are in the same directory as the script for this example

# Define the desired path for the output CSV file.
output_file = "final_predictions_" + timestamp_str + ".csv"
base_csv_uri = "/workspace/data/rag_test_data/scion.csv"
# Create dummy files for demonstration purposes
# In your real case, you would already have these files.
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

new_df = process_json_files(retrival_docs_folder)
print(new_df)
append_new_data_frame_to_base_csv(
    base_csv_uri, output_directory, output_file, new_df
)
# Out:
#             id Prediction_retrieved_article_name_1  \
# 0   row_000001                                  없음
# 1   row_000003                                  없음
# 2   row_000004                                  없음
# 3   row_000005                                  없음
# 4   row_000006                                  없음
# 5   row_000007                                  없음
# 6   row_000011                                  없음
# 7   row_000012                                  없음
# 8   row_000013                                  없음
# 9   row_000014                                  없음
# 10  row_000015                                  없음
# 11  row_000016                                  없음
# 12  row_000017                                  없음
# 13  row_000018                                  없음
# 14  row_000019                                  없음
# 15  row_000020                                  없음
# 16  row_000021                                  없음
# 17  row_000022                                  없음
# 18  row_000023                                  없음
# 19  row_000026                                  없음
# 20  row_000027                                  없음
# 21  row_000028                                  없음
# 22  row_000029                                  없음
# 23  row_000030                                  없음
# 24  row_000031                                  없음
# 25  row_000032                                  없음
# 26  row_000033                                  없음
# 27  row_000034                                  없음
# 28  row_000035                                  없음
# 29  row_000036                                  없음
# 30  row_000038                                  없음
# 31  row_000039                                  없음
# 32  row_000040                                  없음
# 33  row_000041                                  없음
# 34  row_000042                                  없음
# 35  row_000043                                  없음
# 36  row_000044                                  없음
# 37  row_000045                                  없음
# 38  row_000046                                  없음
# 39  row_000047                                  없음
# 40  row_000048                                  없음
# 41  row_000049                                  없음
# 42  row_000050                                  없음
#
#    Prediction_retrieved_article_name_2 Prediction_retrieved_article_name_3  \
# 0                                   없음                                  없음
# 1                                   없음                                  없음
# 2                                   없음                                  없음
# 3                                   없음                                  없음
# 4                                   없음                                  없음
# 5                                   없음                                  없음
# 6                                   없음                                  없음
# 7                                   없음                                  없음
# 8                                   없음                                  없음
# 9                                   없음                                  없음
# 10                                  없음                                  없음
# 11                                  없음                                  없음
# 12                                  없음                                  없음
# 13                                  없음                                  없음
# 14                                  없음                                  없음
# 15                                  없음                                  없음
# 16                                  없음                                  없음
# 17                                  없음                                  없음
# 18                                  없음                                  없음
# 19                                  없음                                  없음
# 20                                  없음                                  없음
# 21                                  없음                                  없음
# 22                                  없음                                  없음
# 23                                  없음                                  없음
# 24                                  없음                                  없음
# 25                                  없음                                  없음
# 26                                  없음                                  없음
# 27                                  없음                                  없음
# 28                                  없음                                  없음
# 29                                  없음                                  없음
# 30                                  없음                                  없음
# 31                                  없음                                  없음
# 32                                  없음                                  없음
# 33                                  없음                                  없음
# 34                                  없음                                  없음
# 35                                  없음                                  없음
# 36                                  없음                                  없음
# 37                                  없음                                  없음
# 38                                  없음                                  없음
# 39                                  없음                                  없음
# 40                                  없음                                  없음
# 41                                  없음                                  없음
# 42                                  없음                                  없음
#
#    Prediction_retrieved_article_name_4 Prediction_retrieved_article_name_5  \
# 0                                   없음                                  없음
# 1                                   없음                                  없음
# 2                                   없음                                  없음
# 3                                   없음                                  없음
# 4                                   없음                                  없음
# 5                                   없음                                  없음
# 6                                   없음                                  없음
# 7                                   없음                                  없음
# 8                                   없음                                  없음
# 9                                   없음                                  없음
# 10                                  없음                                  없음
# 11                                  없음                                  없음
# 12                                  없음                                  없음
# 13                                  없음                                  없음
# 14                                  없음                                  없음
# 15                                  없음                                  없음
# 16                                  없음                                  없음
# 17                                  없음                                  없음
# 18                                  없음                                  없음
# 19                                  없음                                  없음
# 20                                  없음                                  없음
# 21                                  없음                                  없음
# 22                                  없음                                  없음
# 23                                  없음                                  없음
# 24                                  없음                                  없음
# 25                                  없음                                  없음
# 26                                  없음                                  없음
# 27                                  없음                                  없음
# 28                                  없음                                  없음
# 29                                  없음                                  없음
# 30                                  없음                                  없음
# 31                                  없음                                  없음
# 32                                  없음                                  없음
# 33                                  없음                                  없음
# 34                                  없음                                  없음
# 35                                  없음                                  없음
# 36                                  없음                                  없음
# 37                                  없음                                  없음
# 38                                  없음                                  없음
# 39                                  없음                                  없음
# 40                                  없음                                  없음
# 41                                  없음                                  없음
# 42                                  없음                                  없음
#
#    Prediction_retrieved_article_name_6 Prediction_retrieved_article_name_7  \
# 0                                   없음                                  없음
# 1                                   없음                                  없음
# 2                                   없음                                  없음
# 3                                   없음                                  없음
# 4                                   없음                                  없음
# 5                                   없음                                  없음
# 6                                   없음                                  없음
# 7                                   없음                                  없음
# 8                                   없음                                  없음
# 9                                   없음                                  없음
# 10                                  없음                                  없음
# 11                                  없음                                  없음
# 12                                  없음                                  없음
# 13                                  없음                                  없음
# 14                                  없음                                  없음
# 15                                  없음                                  없음
# 16                                  없음                                  없음
# 17                                  없음                                  없음
# 18                                  없음                                  없음
# 19                                  없음                                  없음
# 20                                  없음                                  없음
# 21                                  없음                                  없음
# 22                                  없음                                  없음
# 23                                  없음                                  없음
# 24                                  없음                                  없음
# 25                                  없음                                  없음
# 26                                  없음                                  없음
# 27                                  없음                                  없음
# 28                                  없음                                  없음
# 29                                  없음                                  없음
# 30                                  없음                                  없음
# 31                                  없음                                  없음
# 32                                  없음                                  없음
# 33                                  없음                                  없음
# 34                                  없음                                  없음
# 35                                  없음                                  없음
# 36                                  없음                                  없음
# 37                                  없음                                  없음
# 38                                  없음                                  없음
# 39                                  없음                                  없음
# 40                                  없음                                  없음
# 41                                  없음                                  없음
# 42                                  없음                                  없음
#
#    Prediction_retrieved_article_name_8 Prediction_retrieved_article_name_9  \
# 0                                   없음                                  없음
# 1                                   없음                                  없음
# 2                                   없음                                  없음
# 3                                   없음                                  없음
# 4                                   없음                                  없음
# 5                                   없음                                  없음
# 6                                   없음                                  없음
# 7                                   없음                                  없음
# 8                                   없음                                  없음
# 9                                   없음                                  없음
# 10                                  없음                                  없음
# 11                                  없음                                  없음
# 12                                  없음                                  없음
# 13                                  없음                                  없음
# 14                                  없음                                  없음
# 15                                  없음                                  없음
# 16                                  없음                                  없음
# 17                                  없음                                  없음
# 18                                  없음                                  없음
# 19                                  없음                                  없음
# 20                                  없음                                  없음
# 21                                  없음                                  없음
# 22                                  없음                                  없음
# 23                                  없음                                  없음
# 24                                  없음                                  없음
# 25                                  없음                                  없음
# 26                                  없음                                  없음
# 27                                  없음                                  없음
# 28                                  없음                                  없음
# 29                                  없음                                  없음
# 30                                  없음                                  없음
# 31                                  없음                                  없음
# 32                                  없음                                  없음
# 33                                  없음                                  없음
# 34                                  없음                                  없음
# 35                                  없음                                  없음
# 36                                  없음                                  없음
# 37                                  없음                                  없음
# 38                                  없음                                  없음
# 39                                  없음                                  없음
# 40                                  없음                                  없음
# 41                                  없음                                  없음
# 42                                  없음                                  없음
#
#     ... Prediction_retrieved_article_name_43  \
# 0   ...                                   없음
# 1   ...                                   없음
# 2   ...                                   없음
# 3   ...                                   없음
# 4   ...                                   없음
# 5   ...                                   없음
# 6   ...                                   없음
# 7   ...                                   없음
# 8   ...                                   없음
# 9   ...                                   없음
# 10  ...                                   없음
# 11  ...                                   없음
# 12  ...                                   없음
# 13  ...                                   없음
# 14  ...                                   없음
# 15  ...                                   없음
# 16  ...                                   없음
# 17  ...                                   없음
# 18  ...                                   없음
# 19  ...                                   없음
# 20  ...                                   없음
# 21  ...                                   없음
# 22  ...                                   없음
# 23  ...                                   없음
# 24  ...                                   없음
# 25  ...                                   없음
# 26  ...                                   없음
# 27  ...                                   없음
# 28  ...                                   없음
# 29  ...                                   없음
# 30  ...                                   없음
# 31  ...                                   없음
# 32  ...                                   없음
# 33  ...                                   없음
# 34  ...                                   없음
# 35  ...                                   없음
# 36  ...                                   없음
# 37  ...                                   없음
# 38  ...                                   없음
# 39  ...                                   없음
# 40  ...                                   없음
# 41  ...                                   없음
# 42  ...                                   없음
#
#    Prediction_retrieved_article_name_44 Prediction_retrieved_article_name_45  \
# 0                                    없음                                   없음
# 1                                    없음                                   없음
# 2                                    없음                                   없음
# 3                                    없음                                   없음
# 4                                    없음                                   없음
# 5                                    없음                                   없음
# 6                                    없음                                   없음
# 7                                    없음                                   없음
# 8                                    없음                                   없음
# 9                                    없음                                   없음
# 10                                   없음                                   없음
# 11                                   없음                                   없음
# 12                                   없음                                   없음
# 13                                   없음                                   없음
# 14                                   없음                                   없음
# 15                                   없음                                   없음
# 16                                   없음                                   없음
# 17                                   없음                                   없음
# 18                                   없음                                   없음
# 19                                   없음                                   없음
# 20                                   없음                                   없음
# 21                                   없음                                   없음
# 22                                   없음                                   없음
# 23                                   없음                                   없음
# 24                                   없음                                   없음
# 25                                   없음                                   없음
# 26                                   없음                                   없음
# 27                                   없음                                   없음
# 28                                   없음                                   없음
# 29                                   없음                                   없음
# 30                                   없음                                   없음
# 31                                   없음                                   없음
# 32                                   없음                                   없음
# 33                                   없음                                   없음
# 34                                   없음                                   없음
# 35                                   없음                                   없음
# 36                                   없음                                   없음
# 37                                   없음                                   없음
# 38                                   없음                                   없음
# 39                                   없음                                   없음
# 40                                   없음                                   없음
# 41                                   없음                                   없음
# 42                                   없음                                   없음
#
#    Prediction_retrieved_article_name_46 Prediction_retrieved_article_name_47  \
# 0                                    없음                                   없음
# 1                                    없음                                   없음
# 2                                    없음                                   없음
# 3                                    없음                                   없음
# 4                                    없음                                   없음
# 5                                    없음                                   없음
# 6                                    없음                                   없음
# 7                                    없음                                   없음
# 8                                    없음                                   없음
# 9                                    없음                                   없음
# 10                                   없음                                   없음
# 11                                   없음                                   없음
# 12                                   없음                                   없음
# 13                                   없음                                   없음
# 14                                   없음                                   없음
# 15                                   없음                                   없음
# 16                                   없음                                   없음
# 17                                   없음                                   없음
# 18                                   없음                                   없음
# 19                                   없음                                   없음
# 20                                   없음                                   없음
# 21                                   없음                                   없음
# 22                                   없음                                   없음
# 23                                   없음                                   없음
# 24                                   없음                                   없음
# 25                                   없음                                   없음
# 26                                   없음                                   없음
# 27                                   없음                                   없음
# 28                                   없음                                   없음
# 29                                   없음                                   없음
# 30                                   없음                                   없음
# 31                                   없음                                   없음
# 32                                   없음                                   없음
# 33                                   없음                                   없음
# 34                                   없음                                   없음
# 35                                   없음                                   없음
# 36                                   없음                                   없음
# 37                                   없음                                   없음
# 38                                   없음                                   없음
# 39                                   없음                                   없음
# 40                                   없음                                   없음
# 41                                   없음                                   없음
# 42                                   없음                                   없음
#
#    Prediction_retrieved_article_name_48 Prediction_retrieved_article_name_49  \
# 0                                    없음                                   없음
# 1                                    없음                                   없음
# 2                                    없음                                   없음
# 3                                    없음                                   없음
# 4                                    없음                                   없음
# 5                                    없음                                   없음
# 6                                    없음                                   없음
# 7                                    없음                                   없음
# 8                                    없음                                   없음
# 9                                    없음                                   없음
# 10                                   없음                                   없음
# 11                                   없음                                   없음
# 12                                   없음                                   없음
# 13                                   없음                                   없음
# 14                                   없음                                   없음
# 15                                   없음                                   없음
# 16                                   없음                                   없음
# 17                                   없음                                   없음
# 18                                   없음                                   없음
# 19                                   없음                                   없음
# 20                                   없음                                   없음
# 21                                   없음                                   없음
# 22                                   없음                                   없음
# 23                                   없음                                   없음
# 24                                   없음                                   없음
# 25                                   없음                                   없음
# 26                                   없음                                   없음
# 27                                   없음                                   없음
# 28                                   없음                                   없음
# 29                                   없음                                   없음
# 30                                   없음                                   없음
# 31                                   없음                                   없음
# 32                                   없음                                   없음
# 33                                   없음                                   없음
# 34                                   없음                                   없음
# 35                                   없음                                   없음
# 36                                   없음                                   없음
# 37                                   없음                                   없음
# 38                                   없음                                   없음
# 39                                   없음                                   없음
# 40                                   없음                                   없음
# 41                                   없음                                   없음
# 42                                   없음                                   없음
#
#    Prediction_retrieved_article_name_50  \
# 0                                    없음
# 1                                    없음
# 2                                    없음
# 3                                    없음
# 4                                    없음
# 5                                    없음
# 6                                    없음
# 7                                    없음
# 8                                    없음
# 9                                    없음
# 10                                   없음
# 11                                   없음
# 12                                   없음
# 13                                   없음
# 14                                   없음
# 15                                   없음
# 16                                   없음
# 17                                   없음
# 18                                   없음
# 19                                   없음
# 20                                   없음
# 21                                   없음
# 22                                   없음
# 23                                   없음
# 24                                   없음
# 25                                   없음
# 26                                   없음
# 27                                   없음
# 28                                   없음
# 29                                   없음
# 30                                   없음
# 31                                   없음
# 32                                   없음
# 33                                   없음
# 34                                   없음
# 35                                   없음
# 36                                   없음
# 37                                   없음
# 38                                   없음
# 39                                   없음
# 40                                   없음
# 41                                   없음
# 42                                   없음
#
#                                            Prediction elapsed_times
# 0   {'title': 'Rationale and Structure of the Free...        0.6758
# 1   {'title': 'Approach and Results of a System Le...        0.6758
# 2   {'title': 'Key Features of a Sustainability-Or...        0.6758
# 3   {'title': 'Summary of Machine Learning Applica...        0.6758
# 4   {'answer': {'title': '초등학교 수준 설명 가능한 인공지능 교육의 ...        0.6758
# 5   {'answer': {'title': '생성형 AI 콘텐츠의 가치 유형별 소비자 인...        0.6758
# 6   {'title': 'Summary of the Enabling Framework f...        0.6758
# 7   {'title': 'Main Advances and Challenges in App...        0.6758
# 8   {'title': 'The Environmental and Ethical Impli...        0.6758
# 9   {'title': 'Combination of Phenomenological and...        0.6758
# 10  {'title': 'Key Findings of Socio-Technical Eva...        0.6758
# 11  {'answer': '##제목##
# Big Data 기반 Warehouse Manag...        0.6758
# 12  {'answer': {'title': 'DTG 실 주행데이터와 공간정보를 활용한 연...        0.6758
# 13  {'answer': {'title': '빅데이터 처리 과정별 위험요인 유형 및 우선...        0.6758
# 14  {'answer': {'title': '패키징 분야 빅데이터 분석 기법 및 소비자 ...        0.6758
# 15  {'answer': {'title': '제조 품질 개선을 위한 식스 시그마 기반 B...        0.6758
# 16  {'title': 'Deep Learning for Enhanced Radar Im...        0.6758
# 17  {'answer': {'title': 'Comparison of Deep Learn...        0.6758
# 18  {'title': 'Methodology and Results of CNN, LST...        0.6758
# 19  {'answer': '##제목##
# 클라우드 컴퓨팅 환경에서 오픈소스 딥 러닝 프레임...        0.6758
# 20  {'제목': 'DC 모터 제어 시스템에 딥 러닝 기반 제어기를 적용한 방법 및 PI...        0.6758
# 21  {'answer': {'title': 'DBN 기반 딥 러닝과 SVM 기업부도 예측...        0.6758
# 22  {'title': '비정형 리뷰 데이터를 활용한 고객 평점 예측 딥 러닝 모델 요약...        0.6758
# 23  {'title': 'Go 게임에 적용된 심층 학습 기술 요약', 'introduct...        0.6758
# 24  {'answer': {'title': 'Strategic Landscape and ...        0.6758
# 25  {'answer': {'title': 'Performance Evaluation C...        0.6758
# 26  {'title': 'Key Design Elements and Convergence...        0.6758
# 27  {'title': 'Principal Concerns and Proposed Sol...        0.6758
# 28  {'title': 'Factors Shaping Consumer Purchase A...        0.6758
# 29  {'title': '한국 IT융합 신산업 역량강화요인 도출 연구 요약', 'intr...        0.6758
# 30  {'answer': {'title': '스마트 농업 분야 저탄소 녹색산업 정책 지원...        0.6758
# 31  {'answer': {'title': '국방 IT융합 비즈니스 모델 유형과 핵심 프...        0.6758
# 32  {'answer': '##제목##
# AHP 방법론을 이용한 에너지-IT 융합기술 도출...        0.6758
# 33  {'title': 'Key Findings on Machine Learning Cl...        0.6758
# 34  {'answer': '##The Role of Large-Scale Machine ...        0.6758
# 35  {'title': 'Core Contributions of Spatial and T...        0.6758
# 36  {'title': 'Integration of Hidden Markov Models...        0.6758
# 37  {'title': 'The Essence of Applying Machine and...        0.6758
# 38  {'제목': 'A₃ 아데노신 수용체 조절제 연구의 핵심 성과', '서론': 'A₃ ...        0.6758
# 39  {'answer': {'title': '지식 기반 스케줄링에서 공간적·시간적 적응을...        0.6758
# 40  {'answer': {'title': '잡음 환경에서 시청각 음성인식의 인식률 향상...        0.6758
# 41  {'answer': '##제목##
# Particle Swarm Optimization...        0.6758
# 42  {'answer': '##제목##
# Lifelong Machine Learning 앙...        0.6758
#
# [43 rows x 53 columns]
# --- '/workspace/data/rag_test_data/scion.csv' 파일에서 읽어온 데이터프레임 ---
#             id Prediction_retrieved_article_name_1  \
# 0   row_000001                                  없음
# 1   row_000003                                  없음
# 2   row_000004                                  없음
# 3   row_000005                                  없음
# 4   row_000006                                  없음
# 5   row_000007                                  없음
# 6   row_000011                                  없음
# 7   row_000012                                  없음
# 8   row_000013                                  없음
# 9   row_000014                                  없음
# 10  row_000015                                  없음
# 11  row_000016                                  없음
# 12  row_000017                                  없음
# 13  row_000018                                  없음
# 14  row_000019                                  없음
# 15  row_000020                                  없음
# 16  row_000021                                  없음
# 17  row_000022                                  없음
# 18  row_000023                                  없음
# 19  row_000026                                  없음
# 20  row_000027                                  없음
# 21  row_000028                                  없음
# 22  row_000029                                  없음
# 23  row_000030                                  없음
# 24  row_000031                                  없음
# 25  row_000032                                  없음
# 26  row_000033                                  없음
# 27  row_000034                                  없음
# 28  row_000035                                  없음
# 29  row_000036                                  없음
# 30  row_000038                                  없음
# 31  row_000039                                  없음
# 32  row_000040                                  없음
# 33  row_000041                                  없음
# 34  row_000042                                  없음
# 35  row_000043                                  없음
# 36  row_000044                                  없음
# 37  row_000045                                  없음
# 38  row_000046                                  없음
# 39  row_000047                                  없음
# 40  row_000048                                  없음
# 41  row_000049                                  없음
# 42  row_000050                                  없음
#
#    Prediction_retrieved_article_name_2 Prediction_retrieved_article_name_3  \
# 0                                   없음                                  없음
# 1                                   없음                                  없음
# 2                                   없음                                  없음
# 3                                   없음                                  없음
# 4                                   없음                                  없음
# 5                                   없음                                  없음
# 6                                   없음                                  없음
# 7                                   없음                                  없음
# 8                                   없음                                  없음
# 9                                   없음                                  없음
# 10                                  없음                                  없음
# 11                                  없음                                  없음
# 12                                  없음                                  없음
# 13                                  없음                                  없음
# 14                                  없음                                  없음
# 15                                  없음                                  없음
# 16                                  없음                                  없음
# 17                                  없음                                  없음
# 18                                  없음                                  없음
# 19                                  없음                                  없음
# 20                                  없음                                  없음
# 21                                  없음                                  없음
# 22                                  없음                                  없음
# 23                                  없음                                  없음
# 24                                  없음                                  없음
# 25                                  없음                                  없음
# 26                                  없음                                  없음
# 27                                  없음                                  없음
# 28                                  없음                                  없음
# 29                                  없음                                  없음
# 30                                  없음                                  없음
# 31                                  없음                                  없음
# 32                                  없음                                  없음
# 33                                  없음                                  없음
# 34                                  없음                                  없음
# 35                                  없음                                  없음
# 36                                  없음                                  없음
# 37                                  없음                                  없음
# 38                                  없음                                  없음
# 39                                  없음                                  없음
# 40                                  없음                                  없음
# 41                                  없음                                  없음
# 42                                  없음                                  없음
#
#    Prediction_retrieved_article_name_4 Prediction_retrieved_article_name_5  \
# 0                                   없음                                  없음
# 1                                   없음                                  없음
# 2                                   없음                                  없음
# 3                                   없음                                  없음
# 4                                   없음                                  없음
# 5                                   없음                                  없음
# 6                                   없음                                  없음
# 7                                   없음                                  없음
# 8                                   없음                                  없음
# 9                                   없음                                  없음
# 10                                  없음                                  없음
# 11                                  없음                                  없음
# 12                                  없음                                  없음
# 13                                  없음                                  없음
# 14                                  없음                                  없음
# 15                                  없음                                  없음
# 16                                  없음                                  없음
# 17                                  없음                                  없음
# 18                                  없음                                  없음
# 19                                  없음                                  없음
# 20                                  없음                                  없음
# 21                                  없음                                  없음
# 22                                  없음                                  없음
# 23                                  없음                                  없음
# 24                                  없음                                  없음
# 25                                  없음                                  없음
# 26                                  없음                                  없음
# 27                                  없음                                  없음
# 28                                  없음                                  없음
# 29                                  없음                                  없음
# 30                                  없음                                  없음
# 31                                  없음                                  없음
# 32                                  없음                                  없음
# 33                                  없음                                  없음
# 34                                  없음                                  없음
# 35                                  없음                                  없음
# 36                                  없음                                  없음
# 37                                  없음                                  없음
# 38                                  없음                                  없음
# 39                                  없음                                  없음
# 40                                  없음                                  없음
# 41                                  없음                                  없음
# 42                                  없음                                  없음
#
#    Prediction_retrieved_article_name_6 Prediction_retrieved_article_name_7  \
# 0                                   없음                                  없음
# 1                                   없음                                  없음
# 2                                   없음                                  없음
# 3                                   없음                                  없음
# 4                                   없음                                  없음
# 5                                   없음                                  없음
# 6                                   없음                                  없음
# 7                                   없음                                  없음
# 8                                   없음                                  없음
# 9                                   없음                                  없음
# 10                                  없음                                  없음
# 11                                  없음                                  없음
# 12                                  없음                                  없음
# 13                                  없음                                  없음
# 14                                  없음                                  없음
# 15                                  없음                                  없음
# 16                                  없음                                  없음
# 17                                  없음                                  없음
# 18                                  없음                                  없음
# 19                                  없음                                  없음
# 20                                  없음                                  없음
# 21                                  없음                                  없음
# 22                                  없음                                  없음
# 23                                  없음                                  없음
# 24                                  없음                                  없음
# 25                                  없음                                  없음
# 26                                  없음                                  없음
# 27                                  없음                                  없음
# 28                                  없음                                  없음
# 29                                  없음                                  없음
# 30                                  없음                                  없음
# 31                                  없음                                  없음
# 32                                  없음                                  없음
# 33                                  없음                                  없음
# 34                                  없음                                  없음
# 35                                  없음                                  없음
# 36                                  없음                                  없음
# 37                                  없음                                  없음
# 38                                  없음                                  없음
# 39                                  없음                                  없음
# 40                                  없음                                  없음
# 41                                  없음                                  없음
# 42                                  없음                                  없음
#
#    Prediction_retrieved_article_name_8 Prediction_retrieved_article_name_9  \
# 0                                   없음                                  없음
# 1                                   없음                                  없음
# 2                                   없음                                  없음
# 3                                   없음                                  없음
# 4                                   없음                                  없음
# 5                                   없음                                  없음
# 6                                   없음                                  없음
# 7                                   없음                                  없음
# 8                                   없음                                  없음
# 9                                   없음                                  없음
# 10                                  없음                                  없음
# 11                                  없음                                  없음
# 12                                  없음                                  없음
# 13                                  없음                                  없음
# 14                                  없음                                  없음
# 15                                  없음                                  없음
# 16                                  없음                                  없음
# ...
# 1                                    없음                                   없음
# 2                                    없음                                   없음
# 3                                    없음                                   없음
# 4                                    없음                                   없음
# 5                                    없음                                   없음
# 6                                    없음                                   없음
# 7                                    없음                                   없음
# 8                                    없음                                   없음
# 9                                    없음                                   없음
# 10                                   없음                                   없음
# 11                                   없음                                   없음
# 12                                   없음                                   없음
# 13                                   없음                                   없음
# 14                                   없음                                   없음
# 15                                   없음                                   없음
# 16                                   없음                                   없음
# 17                                   없음                                   없음
# 18                                   없음                                   없음
# 19                                   없음                                   없음
# 20                                   없음                                   없음
# 21                                   없음                                   없음
# 22                                   없음                                   없음
# 23                                   없음                                   없음
# 24                                   없음                                   없음
# 25                                   없음                                   없음
# 26                                   없음                                   없음
# 27                                   없음                                   없음
# 28                                   없음                                   없음
# 29                                   없음                                   없음
# 30                                   없음                                   없음
# 31                                   없음                                   없음
# 32                                   없음                                   없음
# 33                                   없음                                   없음
# 34                                   없음                                   없음
# 35                                   없음                                   없음
# 36                                   없음                                   없음
# 37                                   없음                                   없음
# 38                                   없음                                   없음
# 39                                   없음                                   없음
# 40                                   없음                                   없음
# 41                                   없음                                   없음
# 42                                   없음                                   없음
# 43                                  NaN                                  NaN
# 44                                  NaN                                  NaN
# 45                                  NaN                                  NaN
# 46                                  NaN                                  NaN
# 47                                  NaN                                  NaN
# 48                                  NaN                                  NaN
# 49                                  NaN                                  NaN
#
#    Prediction_retrieved_article_name_47 Prediction_retrieved_article_name_48  \
# 0                                    없음                                   없음
# 1                                    없음                                   없음
# 2                                    없음                                   없음
# 3                                    없음                                   없음
# 4                                    없음                                   없음
# 5                                    없음                                   없음
# 6                                    없음                                   없음
# 7                                    없음                                   없음
# 8                                    없음                                   없음
# 9                                    없음                                   없음
# 10                                   없음                                   없음
# 11                                   없음                                   없음
# 12                                   없음                                   없음
# 13                                   없음                                   없음
# 14                                   없음                                   없음
# 15                                   없음                                   없음
# 16                                   없음                                   없음
# 17                                   없음                                   없음
# 18                                   없음                                   없음
# 19                                   없음                                   없음
# 20                                   없음                                   없음
# 21                                   없음                                   없음
# 22                                   없음                                   없음
# 23                                   없음                                   없음
# 24                                   없음                                   없음
# 25                                   없음                                   없음
# 26                                   없음                                   없음
# 27                                   없음                                   없음
# 28                                   없음                                   없음
# 29                                   없음                                   없음
# 30                                   없음                                   없음
# 31                                   없음                                   없음
# 32                                   없음                                   없음
# 33                                   없음                                   없음
# 34                                   없음                                   없음
# 35                                   없음                                   없음
# 36                                   없음                                   없음
# 37                                   없음                                   없음
# 38                                   없음                                   없음
# 39                                   없음                                   없음
# 40                                   없음                                   없음
# 41                                   없음                                   없음
# 42                                   없음                                   없음
# 43                                  NaN                                  NaN
# 44                                  NaN                                  NaN
# 45                                  NaN                                  NaN
# 46                                  NaN                                  NaN
# 47                                  NaN                                  NaN
# 48                                  NaN                                  NaN
# 49                                  NaN                                  NaN
#
#    Prediction_retrieved_article_name_49 Prediction_retrieved_article_name_50  \
# 0                                    없음                                   없음
# 1                                    없음                                   없음
# 2                                    없음                                   없음
# 3                                    없음                                   없음
# 4                                    없음                                   없음
# 5                                    없음                                   없음
# 6                                    없음                                   없음
# 7                                    없음                                   없음
# 8                                    없음                                   없음
# 9                                    없음                                   없음
# 10                                   없음                                   없음
# 11                                   없음                                   없음
# 12                                   없음                                   없음
# 13                                   없음                                   없음
# 14                                   없음                                   없음
# 15                                   없음                                   없음
# 16                                   없음                                   없음
# 17                                   없음                                   없음
# 18                                   없음                                   없음
# 19                                   없음                                   없음
# 20                                   없음                                   없음
# 21                                   없음                                   없음
# 22                                   없음                                   없음
# 23                                   없음                                   없음
# 24                                   없음                                   없음
# 25                                   없음                                   없음
# 26                                   없음                                   없음
# 27                                   없음                                   없음
# 28                                   없음                                   없음
# 29                                   없음                                   없음
# 30                                   없음                                   없음
# 31                                   없음                                   없음
# 32                                   없음                                   없음
# 33                                   없음                                   없음
# 34                                   없음                                   없음
# 35                                   없음                                   없음
# 36                                   없음                                   없음
# 37                                   없음                                   없음
# 38                                   없음                                   없음
# 39                                   없음                                   없음
# 40                                   없음                                   없음
# 41                                   없음                                   없음
# 42                                   없음                                   없음
# 43                                  NaN                                  NaN
# 44                                  NaN                                  NaN
# 45                                  NaN                                  NaN
# 46                                  NaN                                  NaN
# 47                                  NaN                                  NaN
# 48                                  NaN                                  NaN
# 49                                  NaN                                  NaN
#
#                                            Prediction elapsed_times
# 0   {'title': 'Rationale and Structure of the Free...        0.6758
# 1   {'title': 'Approach and Results of a System Le...        0.6758
# 2   {'title': 'Key Features of a Sustainability-Or...        0.6758
# 3   {'title': 'Summary of Machine Learning Applica...        0.6758
# 4   {'answer': {'title': '초등학교 수준 설명 가능한 인공지능 교육의 ...        0.6758
# 5   {'answer': {'title': '생성형 AI 콘텐츠의 가치 유형별 소비자 인...        0.6758
# 6   {'title': 'Summary of the Enabling Framework f...        0.6758
# 7   {'title': 'Main Advances and Challenges in App...        0.6758
# 8   {'title': 'The Environmental and Ethical Impli...        0.6758
# 9   {'title': 'Combination of Phenomenological and...        0.6758
# 10  {'title': 'Key Findings of Socio-Technical Eva...        0.6758
# 11  {'answer': '##제목##
# Big Data 기반 Warehouse Manag...        0.6758
# 12  {'answer': {'title': 'DTG 실 주행데이터와 공간정보를 활용한 연...        0.6758
# 13  {'answer': {'title': '빅데이터 처리 과정별 위험요인 유형 및 우선...        0.6758
# 14  {'answer': {'title': '패키징 분야 빅데이터 분석 기법 및 소비자 ...        0.6758
# 15  {'answer': {'title': '제조 품질 개선을 위한 식스 시그마 기반 B...        0.6758
# 16  {'title': 'Deep Learning for Enhanced Radar Im...        0.6758
# 17  {'answer': {'title': 'Comparison of Deep Learn...        0.6758
# 18  {'title': 'Methodology and Results of CNN, LST...        0.6758
# 19  {'answer': '##제목##
# 클라우드 컴퓨팅 환경에서 오픈소스 딥 러닝 프레임...        0.6758
# 20  {'제목': 'DC 모터 제어 시스템에 딥 러닝 기반 제어기를 적용한 방법 및 PI...        0.6758
# 21  {'answer': {'title': 'DBN 기반 딥 러닝과 SVM 기업부도 예측...        0.6758
# 22  {'title': '비정형 리뷰 데이터를 활용한 고객 평점 예측 딥 러닝 모델 요약...        0.6758
# 23  {'title': 'Go 게임에 적용된 심층 학습 기술 요약', 'introduct...        0.6758
# 24  {'answer': {'title': 'Strategic Landscape and ...        0.6758
# 25  {'answer': {'title': 'Performance Evaluation C...        0.6758
# 26  {'title': 'Key Design Elements and Convergence...        0.6758
# 27  {'title': 'Principal Concerns and Proposed Sol...        0.6758
# 28  {'title': 'Factors Shaping Consumer Purchase A...        0.6758
# 29  {'title': '한국 IT융합 신산업 역량강화요인 도출 연구 요약', 'intr...        0.6758
# 30  {'answer': {'title': '스마트 농업 분야 저탄소 녹색산업 정책 지원...        0.6758
# 31  {'answer': {'title': '국방 IT융합 비즈니스 모델 유형과 핵심 프...        0.6758
# 32  {'answer': '##제목##
# AHP 방법론을 이용한 에너지-IT 융합기술 도출...        0.6758
# 33  {'title': 'Key Findings on Machine Learning Cl...        0.6758
# 34  {'answer': '##The Role of Large-Scale Machine ...        0.6758
# 35  {'title': 'Core Contributions of Spatial and T...        0.6758
# 36  {'title': 'Integration of Hidden Markov Models...        0.6758
# 37  {'title': 'The Essence of Applying Machine and...        0.6758
# 38  {'제목': 'A₃ 아데노신 수용체 조절제 연구의 핵심 성과', '서론': 'A₃ ...        0.6758
# 39  {'answer': {'title': '지식 기반 스케줄링에서 공간적·시간적 적응을...        0.6758
# 40  {'answer': {'title': '잡음 환경에서 시청각 음성인식의 인식률 향상...        0.6758
# 41  {'answer': '##제목##
# Particle Swarm Optimization...        0.6758
# 42  {'answer': '##제목##
# Lifelong Machine Learning 앙...        0.6758
# 43                                                NaN           NaN
# 44                                                NaN           NaN
# 45                                                NaN           NaN
# 46                                                NaN           NaN
# 47                                                NaN           NaN
# 48                                                NaN           NaN
# 49                                                NaN           NaN
#
# [50 rows x 109 columns]
#
# ==============================
#
# /workspace/data/expr/competition_submission/250912_100344/final_predictions_250912_100344.csv
# 성공: 병합된 데이터가 '/workspace/data/expr/competition_submission/250912_100344/final_predictions_250912_100344.csv' 경로에 저장되었습니다.

# %% [markdown]
# configure base execution
# python -m retrieval_system.main   --config_json /workspace/configs/query_encoder/config_PwC-Embedding_expr.json   --questions_jsonl /workspace/data/expr/singlehop_decompose.jsonl   --range 1-50   --top_k 50   --device auto --schema_json /workspace/configs/csv_schema/test_3.json
#
# excution by manual
# python -m retrieval_system.main   --vectordb_csv /workspace/results/vectordb/250911_072731/vector_db_PwC_test_SamilPwC-AXNode-GenAI_PwC-Embedding_expr.csv   --config_json /workspace/configs/query_encoder/config_gte-multilingual-base.json   --questions_jsonl /workspace/data/expr/singlehop_decompose.jsonl   --range 1-50   --top_k 50   --device auto --schema_json /workspace/configs/csv_schema/test_3.json
